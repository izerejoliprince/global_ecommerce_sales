# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel(r"C:\Users\user\Desktop\FreshMart Supermarket..xlsx")
data
# Out:
#     Month  Sales
# 0       1    850
# 1       2    920
# 2       3    980
# 3       4   1100
# 4       5   1180
# 5       6   1270
# 6       7   1360
# 7       8   1450
# 8       9   1550
# 9      10   1680
# 10     11   1800
# 11     12   1920

# %%
Month = np.array(data["Month"])
Sales = np.array(data["Sales"])

# %%
trend = np.
