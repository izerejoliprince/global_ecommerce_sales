# %%
# !pip install ipywidgets
# Out:
# ...
#    ---------------------------------------- 0.0/914.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/914.9 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/914.9 kB ? eta -:--:--
#    ---------------------------------------- 914.9/914.9 kB 2.0 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.2 MB 372.9 kB/s eta 0:00:05
#    --------- ------------------------------ 0.5/2.2 MB 372.9 kB/s eta 0:00:05
#    ------------------- -------------------- 1.0/2.2 MB 699.0 kB/s eta 0:00:02
#    ----------------------- ---------------- 1.3/2.2 MB 737.4 kB/s eta 0:00:02
# ...
