# %%
from sklearn.metrics import mean_squared_error

# %%
actual = [100, 200, 300]
prediction = [80, 220, 280]

# %%
mse = mean_squared_error(actual, prediction)
print(mse)
# Out:
# 400.0

# %%
import numpy as np

x = np.array([1, 2, 3, 4])
y = np.array([2, 4, 6, 8])

# %%
b = 0

# %%
prediction = b * x

# %%
prediction
# Out:
# array([0, 0, 0, 0])
