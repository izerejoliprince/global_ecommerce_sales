# %%
import numpy as np

# %%
x = np.array([10, 20, 30, 40])

# %%
x + 10
# Out:
# array([20, 30, 40, 50])

# %%
x
# Out:
# array([10, 20, 30, 40])

# %%
x * 2
# Out:
# array([20, 40, 60, 80])

# %%
x / 10
# Out:
# array([1., 2., 3., 4.])

# %%
np.mean(x)
# Out:
# np.float64(25.0)

# %%
np.std(x)
# Out:
# np.float64(11.180339887498949)

# %%
prices = np.array([100000, 200000, 300000, 400000])

# %%
min_price = np.min(prices)
max_price = np.max(prices)

# %%
normalized = (prices - min_price) / (max_price - min_price)
print(normalized)
# Out:
# [0.         0.33333333 0.66666667 1.        ]

# %%
actual = np.array([100, 200, 300])
predicted = np.array([110, 190, 280])

# %%
mse = np.mean((actual - predicted) ** 2)

# %%
mse
# Out:
# np.float64(200.0)

# %%
import numpy as np

sells = np.array([100000, 150000, 200000, 250000, 300000])

# %%
print(sells.shape)
# Out:
# (5,)

# %%
print(sells.reshape(-1,1))
# Out:
# [[100000]
#  [150000]
#  [200000]
#  [250000]
#  [300000]]

# %%
min_sells = np.min(sells)
max_sells = np.max(sells)

# %%
min_sells
# Out:
# np.int64(100000)

# %%
max_sells
# Out:
# np.int64(300000)

# %%
average = np.mean(sells)
average
# Out:
# np.float64(200000.0)

# %%
normalized = (sells - min_sells) / (max_sells - min_sells)
normalized
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
X = np.array([
    [20, 30000],
    [25, 40000],
    [30, 50000],
    [35, 60000],
    [40, 70000]
])

# %%
X.shape
# Out:
# (5, 2)

# %%
actual = np.array([100, 200, 300, 400])

predicted = np.array([110, 190, 280, 420])

# %%
mse = np.mean((actual - predicted) ** 2)
print(mse)
# Out:
# 250.0
