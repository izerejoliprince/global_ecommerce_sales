# %%
import pandas as pd
data = ({
    "Age": [25, 30, 35, 40, 45],
    "Income": [30000, 45000, 60000, 70000, 90000],
    "Spending": [500, 800, 1200, 1600, 2200]
})

data = pd.DataFrame(data)
print(data)
# Out:
#    Age  Income  Spending
# 0   25   30000       500
# 1   30   45000       800
# 2   35   60000      1200
# 3   40   70000      1600
# 4   45   90000      2200

# %%
data.head(3)
# Out:
#    Age  Income  Spending
# 0   25   30000       500
# 1   30   45000       800
# 2   35   60000      1200

# %%
data.tail(3)
# Out:
#    Age  Income  Spending
# 2   35   60000      1200
# 3   40   70000      1600
# 4   45   90000      2200

# %%
data.shape
# Out:
# (5, 3)

# %%
data.columns
# Out:
# Index(['Age', 'Income', 'Spending'], dtype='object')

# %%
data.columns.tolist()
# Out:
# ['Age', 'Income', 'Spending']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       5 non-null      int64
#  1   Income    5 non-null      int64
#  2   Spending  5 non-null      int64
# dtypes: int64(3)
# memory usage: 248.0 bytes

# %%
data.dtypes
# Out:
# Age         int64
# Income      int64
# Spending    int64
# dtype: object

# %%
data.describe()
# Out:
#              Age        Income     Spending
# count   5.000000      5.000000     5.000000
# mean   35.000000  59000.000000  1260.000000
# std     7.905694  23021.728866   669.328021
# min    25.000000  30000.000000   500.000000
# 25%    30.000000  45000.000000   800.000000
# 50%    35.000000  60000.000000  1200.000000
# 75%    40.000000  70000.000000  1600.000000
# max    45.000000  90000.000000  2200.000000

# %%
data["Age"]
# Out:
# 0    25
# 1    30
# 2    35
# 3    40
# 4    45
# Name: Age, dtype: int64

# %%
data[["Age", "Spending"]]
# Out:
#    Age  Spending
# 0   25       500
# 1   30       800
# 2   35      1200
# 3   40      1600
# 4   45      2200

# %%
data[data["Income"] > 50000]
# Out:
#    Age  Income  Spending
# 2   35   60000      1200
# 3   40   70000      1600
# 4   45   90000      2200

# %%
data[data["Age"] > 25]
# Out:
#    Age  Income  Spending
# 1   30   45000       800
# 2   35   60000      1200
# 3   40   70000      1600
# 4   45   90000      2200

# %%
data[(data["Income"] > 50000) & (data["Age"] > 30)]
# Out:
#    Age  Income  Spending
# 2   35   60000      1200
# 3   40   70000      1600
# 4   45   90000      2200

# %%
data[(data["Income"] > 50000) | (data["Age"] > 40)]
# Out:
#    Age  Income  Spending
# 2   35   60000      1200
# 3   40   70000      1600
# 4   45   90000      2200

# %%
data[data["Age"] == 40]
# Out:
#    Age  Income  Spending
# 3   40   70000      1600

# %%
import pandas as pd
data2 = ({
    "Age": [25, "", 35, 40, 45],
    "Income": [30000, "", 60000, 70000, 90000],
    "Spending": [500, "", 1200, 1600, 2200]
})

data2 = pd.DataFrame(data2)
print(data2)
# Out:
#   Age Income Spending
# 0  25  30000      500
# 1
# 2  35  60000     1200
# 3  40  70000     1600
# 4  45  90000     2200

# %%
data2.isnull().sum()
# Out:
# Age         0
# Income      0
# Spending    0
# dtype: int64

# %%
data2.dropna()
# Out:
#   Age Income Spending
# 0  25  30000      500
# 1
# 2  35  60000     1200
# 3  40  70000     1600
# 4  45  90000     2200

# %%
data.dropna()
# Out:
#    Age  Income  Spending
# 0   25   30000       500
# 1   30   45000       800
# 2   35   60000      1200
# 3   40   70000      1600
# 4   45   90000      2200

# %%
data2["Age"] = data2["Age"].fillna(data2["Age"].mode())
data2["Age"]
# Out:
# 0    25
# 1
# 2    35
# 3    40
# 4    45
# Name: Age, dtype: object

# %%
data2.dropna()
# Out:
#   Age Income Spending
# 0  25  30000      500
# 1
# 2  35  60000     1200
# 3  40  70000     1600
# 4  45  90000     2200

# %%
data["Income"] = data["Income"].fillna(data["Income"].mean())
data["Income"]
# Out:
# 0    30000
# 1    45000
# 2    60000
# 3    70000
# 4    90000
# Name: Income, dtype: int64

# %%
data1 = ({
    "Age": [25, 30, 35],
    "Income": [30000, 45000, 60000],
    "City": ["Kigali", "Huye", "Kigali"]
})

data1 = pd.DataFrame(data1)
print(data1)
# Out:
#    Age  Income    City
# 0   25   30000  Kigali
# 1   30   45000    Huye
# 2   35   60000  Kigali

# %%
pd.get_dummies(data1, columns=["City"])
# Out:
#    Age  Income  City_Huye  City_Kigali
# 0   25   30000      False         True
# 1   30   45000       True        False
# 2   35   60000      False         True

# %%
pd.get_dummies(data1, columns=["City"])
# Out:
#    Age  Income  City_Huye  City_Kigali
# 0   25   30000      False         True
# 1   30   45000       True        False
# 2   35   60000      False         True

# %%
data1
# Out:
#    Age  Income    City
# 0   25   30000  Kigali
# 1   30   45000    Huye
# 2   35   60000  Kigali

# %%
data1 = data1.drop("City", axis = 1)
data1
# Out:
#    Age  Income
# 0   25   30000
# 1   30   45000
# 2   35   60000

# %%
data1 = data1.rename(columns={"Income": "Monthly Income"})
data1
# Out:
#    Age  Monthly Income
# 0   25           30000
# 1   30           45000
# 2   35           60000

# %%
data1 = data1.rename(columns={"Age": "Age of Customers"})
data1
# Out:
#    Age of Customers  Monthly Income
# 0                25           30000
# 1                30           45000
# 2                35           60000

# %%
data1
# Out:
#    Age of Customers  Monthly Income
# 0                25           30000
# 1                30           45000
# 2                35           60000

# %%
data1["Annual_Income"] = data1["Monthly Income"] * 12

# %%
data1
# Out:
#    Age of Customers  Monthly Income  Annual_Income
# 0                25           30000         360000
# 1                30           45000         540000
# 2                35           60000         720000

# %%
data1.sort_values("Monthly Income")
# Out:
#    Age of Customers  Monthly Income  Annual_Income
# 0                25           30000         360000
# 1                30           45000         540000
# 2                35           60000         720000

# %%
data1.sort_values("Monthly Income", ascending=False)
# Out:
#    Age of Customers  Monthly Income  Annual_Income
# 2                35           60000         720000
# 1                30           45000         540000
# 0                25           30000         360000

# %%
data1.sort_values("Monthly Income", ascending=True)
# Out:
#    Age of Customers  Monthly Income  Annual_Income
# 0                25           30000         360000
# 1                30           45000         540000
# 2                35           60000         720000

# %%
data1[data1["Monthly Income"] >50000]
# Out:
#    Age of Customers  Monthly Income  Annual_Income
# 2                35           60000         720000

# %%
data1[(data1["Age of Customers"] == 30) & (data1["Annual_Income"] == 540000)]
# Out:
#    Age of Customers  Monthly Income  Annual_Income
# 1                30           45000         540000

# %%
data1.loc[data1["Monthly Income"] > 50000]
# Out:
#    Age of Customers  Monthly Income  Annual_Income
# 2                35           60000         720000

# %%
data1.loc[data1["Monthly Income"] > 50000, ["Age of Customers", "Monthly Income"]]
# Out:
#    Age of Customers  Monthly Income
# 2                35           60000

# %%
data1.iloc[0]
# Out:
# Age of Customers        25
# Monthly Income       30000
# Annual_Income       360000
# Name: 0, dtype: int64

# %%
data1.iloc[0:3]
# Out:
#    Age of Customers  Monthly Income  Annual_Income
# 0                25           30000         360000
# 1                30           45000         540000
# 2                35           60000         720000

# %%
data1.iloc[:, 0:2]
# Out:
#    Age of Customers  Monthly Income
# 0                25           30000
# 1                30           45000
# 2                35           60000

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data1.duplicated().sum()
# Out:
# np.int64(0)

# %%
data1.duplicated().sum()
# Out:
# np.int64(0)

# %%
data1.duplicated().sum()
# Out:
# np.int64(0)

# %%
data1.drop_duplicates()
# Out:
#    Age of Customers  Monthly Income  Annual_Income
# 0                25           30000         360000
# 1                30           45000         540000
# 2                35           60000         720000

# %%
data.drop_duplicates()
# Out:
#    Age  Income  Spending
# 0   25   30000       500
# 1   30   45000       800
# 2   35   60000      1200
# 3   40   70000      1600
# 4   45   90000      2200

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.head()
# Out:
#    Age  Income  Spending
# 0   25   30000       500
# 1   30   45000       800
# 2   35   60000      1200
# 3   40   70000      1600
# 4   45   90000      2200

# %%
data.tail()
# Out:
#    Age  Income  Spending
# 0   25   30000       500
# 1   30   45000       800
# 2   35   60000      1200
# 3   40   70000      1600
# 4   45   90000      2200

# %%
data.shape
# Out:
# (5, 3)

# %%
data.columns
# Out:
# Index(['Age', 'Income', 'Spending'], dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       5 non-null      int64
#  1   Income    5 non-null      int64
#  2   Spending  5 non-null      int64
# dtypes: int64(3)
# memory usage: 248.0 bytes

# %%
data.describe()
# Out:
#              Age        Income     Spending
# count   5.000000      5.000000     5.000000
# mean   35.000000  59000.000000  1260.000000
# std     7.905694  23021.728866   669.328021
# min    25.000000  30000.000000   500.000000
# 25%    30.000000  45000.000000   800.000000
# 50%    35.000000  60000.000000  1200.000000
# 75%    40.000000  70000.000000  1600.000000
# max    45.000000  90000.000000  2200.000000

# %%
data.isnull().sum()
# Out:
# Age         0
# Income      0
# Spending    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.drop_duplicates()
# Out:
#    Age  Income  Spending
# 0   25   30000       500
# 1   30   45000       800
# 2   35   60000      1200
# 3   40   70000      1600
# 4   45   90000      2200

# %%
data["Income"] = data["Income"].fillna(data["Income"].mode())
data["Income"]
# Out:
# 0    30000
# 1    45000
# 2    60000
# 3    70000
# 4    90000
# Name: Income, dtype: int64

# %%
data1
# Out:
#    Age of Customers  Monthly Income  Annual_Income
# 0                25           30000         360000
# 1                30           45000         540000
# 2                35           60000         720000

# %%
data2
# Out:
#   Age Income Spending
# 0  25  30000      500
# 1
# 2  35  60000     1200
# 3  40  70000     1600
# 4  45  90000     2200

# %%
import pandas as pd

dat1 = pd.DataFrame({
    "Gender": ["Male", "Female", "Female", "Male", "Male"]
})

print(dat1)
# Out:
#    Gender
# 0    Male
# 1  Female
# 2  Female
# 3    Male
# 4    Male

# %%
dat1["Gender"] = dat1["Gender"].map({
    "Male": 1,
    "Female": 0
})

# %%
dat1
# Out:
#    Gender
# 0       1
# 1       0
# 2       0
# 3       1
# 4       1
