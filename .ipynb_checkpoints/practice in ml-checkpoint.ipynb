# %%
import pandas as pd 
data = pd.read_excel(r"C:\Users\user\Desktop\spending.xlsx")
data
# Out:
#    Age  Income  Family_Size  Spending
# 0   25   30000            2       500
# 1   35   50000            4      1200
# 2   45   80000            5      2500

# %%
data.head(1)
# Out:
#    Age  Income  Family_Size  Spending
# 0   25   30000            2       500

# %%
data.tail(1)
# Out:
#    Age  Income  Family_Size  Spending
# 2   45   80000            5      2500

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          3 non-null      int64
#  1   Income       3 non-null      int64
#  2   Family_Size  3 non-null      int64
#  3   Spending     3 non-null      int64
# dtypes: int64(4)
# memory usage: 224.0 bytes

# %%
data.describe()
# Out:
#         Age        Income  Family_Size     Spending
# count   3.0      3.000000     3.000000     3.000000
# mean   35.0  53333.333333     3.666667  1400.000000
# std    10.0  25166.114784     1.527525  1014.889157
# min    25.0  30000.000000     2.000000   500.000000
# 25%    30.0  40000.000000     3.000000   850.000000
# 50%    35.0  50000.000000     4.000000  1200.000000
# 75%    40.0  65000.000000     4.500000  1850.000000
# max    45.0  80000.000000     5.000000  2500.000000

# %%
data.columns
# Out:
# Index(['Age', 'Income', 'Family_Size', 'Spending'], dtype='object')

# %%
data.isnull().sum()
# Out:
# Age            0
# Income         0
# Family_Size    0
# Spending       0
# dtype: int64

# %%
x = data.drop("Spending", axis=1)
y = data["Spending"]

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size = 0.3, random_state = 1)

# %%
from sklearn. linear_model import BayesianRidge

# %%
model = BayesianRidge()

# %%
model.fit(xtrain, ytrain)
# Out:
# BayesianRidge()

# %%
prediction, std = model.predict(xtest, return_std=True)

# %%
prediction, std
# Out:
# (array([333.33328326]),
#  0    0.651795
#  dtype: float64)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
print(mean_squared_error(ytest, prediction))
print(mean_absolute_error(ytest, prediction))
print(r2_score(ytest, prediction))
# Out:
# 27777.794467551208
# 166.66671673597943
# nan
# C:\Users\user\miniconda3\envs\test\lib\site-packages\sklearn\metrics\_regression.py:1283: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
